# %%
#Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the CSV file
df = pd.read_csv("HR Dataset.csv")

# %%
# Perform EDA
print("Dataset shape:", df.shape)
print("\nDataset info:")
df.info()

print("\nSummary statistics:")
print(df.describe())

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Dataset shape: (5000, 21)
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               5000 non-null   int64
#  1   EmployeeID               5000 non-null   int64
#  2   Age                      5000 non-null   int64
#  3   Gender                   5000 non-null   object
#  4   Department               5000 non-null   object
#  5   YearsOfExperience        5000 non-null   int64
#  6   EducationLevel           5000 non-null   int64
#  7   Salary                   5000 non-null   int64
#  8   PerformanceRating        5000 non-null   int64
#  9   WorkLifeBalance          5000 non-null   int64
#  10  EmployeeSatisfaction     5000 non-null   int64
#  11  TrainingHours            5000 non-null   int64
#  12  YearsInCurrentRole       5000 non-null   int64
#  13  YearsSinceLastPromotion  5000 non-null   int64
#  14  YearsWithCurrentManager  5000 non-null   int64
#  15  Attrition                5000 non-null   object
#  16  ProjectInvolvement       5000 non-null   object
#  17  Skills                   5000 non-null   object
#  18  TrainingEffectiveness    5000 non-null   int64
#  19  Certification            5000 non-null   object
#  20  LastTrainingDate         5000 non-null   object
# dtypes: int64(14), object(7)
# memory usage: 820.4+ KB
#
# Summary statistics:
#         Unnamed: 0   EmployeeID          Age  YearsOfExperience  \
# count  5000.000000  5000.000000  5000.000000        5000.000000
# mean   2499.500000  2500.500000    41.726200           6.983600
# std    1443.520003  1443.520003    11.506299           4.390625
# min       0.000000     1.000000    22.000000           0.000000
# 25%    1249.750000  1250.750000    32.000000           3.000000
# 50%    2499.500000  2500.500000    42.000000           7.000000
# 75%    3749.250000  3750.250000    52.000000          11.000000
# max    4999.000000  5000.000000    61.000000          14.000000
#
#        EducationLevel         Salary  PerformanceRating  WorkLifeBalance  \
# count     5000.000000    5000.000000        5000.000000      5000.000000
# mean         2.955800   89676.669000           3.066000         3.017600
# std          1.408206   34646.145052           1.430403         1.415659
# min          1.000000   30016.000000           1.000000         1.000000
# 25%          2.000000   58958.750000           2.000000         2.000000
# 50%          3.000000   90098.500000           3.000000         3.000000
# 75%          4.000000  119381.750000           4.000000         4.000000
# max          5.000000  149989.000000           5.000000         5.000000
#
#        EmployeeSatisfaction  TrainingHours  YearsInCurrentRole  \
# count           5000.000000    5000.000000         5000.000000
# mean               2.994800      53.554600            4.514600
# std                1.408393      26.022522            2.863953
# min                1.000000      10.000000            0.000000
# 25%                2.000000      31.000000            2.000000
# 50%                3.000000      53.000000            5.000000
# 75%                4.000000      76.000000            7.000000
# max                5.000000      99.000000            9.000000
#
#        YearsSinceLastPromotion  YearsWithCurrentManager  TrainingEffectiveness
# count              5000.000000              5000.000000            5000.000000
# mean                  4.526400                 4.524800               2.999600
# std                   2.861912                 2.844258               1.425344
# min                   0.000000                 0.000000               1.000000
# 25%                   2.000000                 2.000000               2.000000
# 50%                   5.000000                 5.000000               3.000000
# 75%                   7.000000                 7.000000               4.000000
# max                   9.000000                 9.000000               5.000000
#
# Missing values:
# Unnamed: 0                 0
# EmployeeID                 0
# Age                        0
# Gender                     0
# Department                 0
# YearsOfExperience          0
# EducationLevel             0
# Salary                     0
# PerformanceRating          0
# WorkLifeBalance            0
# EmployeeSatisfaction       0
# TrainingHours              0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrentManager    0
# Attrition                  0
# ProjectInvolvement         0
# Skills                     0
# TrainingEffectiveness      0
# Certification              0
# LastTrainingDate           0
# dtype: int64

# %%
# Visualize distributions of numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(20, 15))
fig.suptitle("Distribution of Numerical Variables")
for i, col in enumerate(numerical_cols[:9]):
    sns.histplot(df[col], ax=axes[i//3, i%3], kde=True)
plt.tight_layout()
plt.show()
